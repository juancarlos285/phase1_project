# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# %matplotlib inline
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
#Reads the csv
df = pd.read_csv('../data/AviationData.csv', encoding='latin-1')

df['Aircraft.Category'].value_counts()
# Out:
# /var/folders/ws/w4d9z41n7vj1pg3kqv95frm80000gn/T/ipykernel_93973/1154597234.py:2: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/AviationData.csv', encoding='latin-1')
# Aircraft.Category
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64

# %%
df.head()

# %%
accident_types = df['Investigation.Type'].unique()
airplane_df = df[df['Aircraft.Category'] == 'Airplane']
airplane_df = airplane_df.set_index(['Event.Id'])

# %%
group_by_airplane = airplane_df.groupby('Make').sum(numeric_only=True)
accidents_by_make = airplane_df['Make'].value_counts()
accidents_by_make
# Out:
# Make
# CESSNA             4867
# Cessna             3608
# PIPER              2805
# Piper              1910
# BOEING             1037
#                    ...
# GLINES                1
# RAMMEL THOMAS W       1
# HEMMER                1
# W.H. Hunnicutt        1
# ORLICAN S R O         1
# Name: count, Length: 3874, dtype: int64

# %%
locations_list = df.Location.dropna().unique()

geolocator = Nominatim(user_agent='phase1_project')

# %%
len(locations_list)

# %%
#DO NOT RUN
# def coordinate_finder(location=str):
    info = geolocator.geocode(location)
    return info
# def geo_df_generator(locations=list):
    df = {'Location': [],
        'Longitude_city': [],
        'Latitude_city': []}
    try:
        for city in locations:
            get_info = coordinate_finder(city)
            if get_info != None:
                longitude = get_info.longitude
                latitude = get_info.latitude
                df['Location'].append(city)
                df['Longitude_city'].append(longitude)
                df['Latitude_city'].append(latitude)
        return df
    except AttributeError as err:
        print(err, city)
    except geopy.exc.GeocoderServiceError as terr:
        print(terr, city)

# %%
#DO NOT RUN
# coordinates_df = pd.DataFrame(geo_df_generator(locations_list[:1000]))

# %% [markdown]
# ## Location cleaning

# %%
# Makes all locations upper case
airplane_df['Location'] = airplane_df['Location'].replace({np.nan: 'UNK'})
airplane_df['Location'] = airplane_df['Location'].str.upper().str.strip(to_strip=',')
airplane_df['Location'].loc[airplane_df['Country'] == 'United States'].str.slice(start=-2)

#Creates State column for accidents in the US
airplane_df['State'] = df['Location'].fillna('')
airplane_df['State'] = airplane_df['Location'].map(lambda x: x[-2:])
airplane_df['State'].loc[airplane_df['Country'] != 'United States'] = 'UNK'
# Out:
# /var/folders/ws/w4d9z41n7vj1pg3kqv95frm80000gn/T/ipykernel_93973/2247685329.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airplane_df['State'].loc[airplane_df['Country'] != 'United States'] = 'UNK'

# %%
state_counts = [(state, count) for state, count in airplane_df['State'].value_counts().items()]

# %%
for state, count in state_counts:
    x = airplane_df['Location'].loc[airplane_df['State'] == state].sample(1)
    print(x)
# Out:
# Event.Id
# 20201227102456    NABERN-TECK, GERMANY
# Name: Location, dtype: object
# Event.Id
# 20181028X02003    FIILMORE, CA
# Name: Location, dtype: object
# Event.Id
# 20090930X21219    INKS LAKE, TX
# Name: Location, dtype: object
# Event.Id
# 20170212X02502    ST. PETERSBURG, FL
# Name: Location, dtype: object
# Event.Id
# 20020917X04210    NEAR CLEAR, AK
# Name: Location, dtype: object
# Event.Id
# 20141019X50339    BULLHEAD CITY, AZ
# Name: Location, dtype: object
# Event.Id
# 20090707X13323    STEAMBOAT SPRINGS, CO
# Name: Location, dtype: object
# Event.Id
# 20160921X20513    LOPEZ ISLAND, WA
# Name: Location, dtype: object
# Event.Id
# 20100215X94124    BRUNSWICK, GA
# Name: Location, dtype: object
# Event.Id
# 20091214X41802    CHARLOTTE, NC
# Name: Location, dtype: object
# Event.Id
# 20070426X00458    CHICAGO, IL
# Name: Location, dtype: object
# Event.Id
# 20040628X00875    MIDLAND, MI
# Name: Location, dtype: object
# Event.Id
# 20020917X05144    SALMON, ID
# Name: Location, dtype: object
# Event.Id
# 20170530X84515    DIAMOND POINT, NY
# Name: Location, dtype: object
# Event.Id
# 20180228X13242    ASHLAND, OH
# Name: Location, dtype: object
# Event.Id
# 20210907103807    ENTERPRISE, OR
# Name: Location, dtype: object
# Event.Id
# 20190808X71425    HATBORO, PA
# Name: Location, dtype: object
# Event.Id
# 20070312X00277    ST. LOUIS, MO
# Name: Location, dtype: object
# Event.Id
# 20040813X01220    MERRILL, WI
# Name: Location, dtype: object
# Event.Id
# 20020917X01829    GRAND MARAIS, MN
# Name: Location, dtype: object
# Event.Id
# 20091003X75505    GLOUCESTER, VA
# Name: Location, dtype: object
# Event.Id
# 20060627X00833    TUCKERMAN, AR
# Name: Location, dtype: object
# Event.Id
# 20100718X52341    MONUMENT VALLEY, UT
# Name: Location, dtype: object
# Event.Id
# 20180530X44625    TONOPAH, NV
# Name: Location, dtype: object
# Event.Id
# 20150803X45031    NORTH VERNON, IN
# Name: Location, dtype: object
# Event.Id
# 20180529X91121    WICHITA, KS
# Name: Location, dtype: object
# Event.Id
# 20181106X01336    TEXICO, NM
# Name: Location, dtype: object
# Event.Id
# 20080128X00113    MUSKOGEE, OK
# Name: Location, dtype: object
# Event.Id
# 20160116X22241    KINGSTON, TN
# Name: Location, dtype: object
# Event.Id
# 20140703X75746    GULF SHORES, AL
# Name: Location, dtype: object
# Event.Id
# 20220328104841    BELGRADE, MT
# Name: Location, dtype: object
# Event.Id
# 20020917X03438    REEVES, LA
# Name: Location, dtype: object
# Event.Id
# 20220503105036    SENECA, SC
# Name: Location, dtype: object
# Event.Id
# 20100914X53827    TOMS RIVER, NJ
# Name: Location, dtype: object
# Event.Id
# 20020917X01736    WESTMINSTER, MD
# Name: Location, dtype: object
# Event.Id
# 20041028X01716    OXFORD, IA
# Name: Location, dtype: object
# Event.Id
# 20031120X01929    MANSFIELD, MA
# Name: Location, dtype: object
# Event.Id
# 20160926X44236    GREENWOOD, MS
# Name: Location, dtype: object
# Event.Id
# 20111109X90044    CHEYENNE, WY
# Name: Location, dtype: object
# Event.Id
# 20170810X63546    KEARNEY, NE
# Name: Location, dtype: object
# Event.Id
# 20130109X40425    BEAR BRANCH, KY
# Name: Location, dtype: object
# Event.Id
# 20170524X92701    SIDNEY, ME
# Name: Location, dtype: object
# Event.Id
# 20040618X00834    HOPE, ND
# Name: Location, dtype: object
# Event.Id
# 20140611X81726    WINNER, SD
# Name: Location, dtype: object
# Event.Id
# 20020917X05097    NEW HAVEN, CT
# Name: Location, dtype: object
# Event.Id
# 20110227X93844    WELCH, WV
# Name: Location, dtype: object
# Event.Id
# 20160531X61809    WAIANAE, HI
# Name: Location, dtype: object
# Event.Id
# 20090613X04639    GILFORD, NH
# Name: Location, dtype: object
# Event.Id
# 20140521X71202    WARREN, VT
# Name: Location, dtype: object
# Event.Id
# 20120509X23741    CULEBRA, PR
# Name: Location, dtype: object
# Event.Id
# 20120717X03630    PAWTUCKET, RI
# Name: Location, dtype: object
# Event.Id
# 20001213X26456    SELBYVILLE, DE
# Name: Location, dtype: object
# Event.Id
# 20211102104197    CIACANESTI, OF
# Name: Location, dtype: object
# Event.Id
# 20181025X55256    ATLANTIC OCEAN, AO
# Name: Location, dtype: object
# Event.Id
# 20080723X01111    PACIFIC OCEAN
# Name: Location, dtype: object
# Event.Id
# 20001213X27446    MIDWAY ISLANDS, PO
# Name: Location, dtype: object
# Event.Id
# 20020917X01766    WASHINGTON, DC
# Name: Location, dtype: object
# Event.Id
# 20150504X14247    TAMUNING
# Name: Location, dtype: object
# Event.Id
# 20191021X53431    UNKNOWN
# Name: Location, dtype: object
# Event.Id
# 20090306X84920
# Name: Location, dtype: object
# Event.Id
# 20171207X11110    ST. CROIX
# Name: Location, dtype: object
# Event.Id
# 20190912X74625    CHARLOTTE AMALIE
# Name: Location, dtype: object
# Event.Id
# 20001208X08606    NIMITZ HILL, GU
# Name: Location, dtype: object
# Event.Id
# 20111005X34605    AGANA
# Name: Location, dtype: object
# Event.Id
# 20141120X02000    WHITNEY
# Name: Location, dtype: object
# Event.Id
# 20180108X90308    GULF OF MEXICO, GM
# Name: Location, dtype: object
# Event.Id
# 20091029X54134    CHRISTIANSTED
# Name: Location, dtype: object
# Event.Id
# 20101230X05139    ST. THOMAS
# Name: Location, dtype: object
# Event.Id
# 20080808X01181    CHARLOTTE AMALI
# Name: Location, dtype: object
# Event.Id
# 20071025X01653    ST.CROIX, VI
# Name: Location, dtype: object
# Event.Id
# 20181204X05247    SANTA RITA
# Name: Location, dtype: object

# %% [markdown]
# - ATL: Atlantic Ocean
# - NMI: Northern Mariana Islands
# - USVI: US Virgin Islands
# - GU: Guam
# - GM: Gulf of Mexico

# %%
airplane_df['State'] = airplane_df['State'].replace({'AO': 'ATL', 'AN': 'NMI',
                             'PO': 'GU', 'NG': 'GU', 'IX': 'USVI',
                             'IE': 'USVI', 'NA': 'GU', 'ED': 'USVI',
                             'AS': 'USVI', 'TA': 'GU'})

# %% [markdown]
# ## Airport Codes Cleaning

# %%
#look at dataset
airplane_df.head()

# Count the number of NaN values in the 'Airport.Code' column
missing_values_count = airplane_df['Airport.Code'].isnull().sum()

# Display the count and percentage of missing values
total_entries = len(airplane_df['Airport.Code'])
percentage_missing = (missing_values_count / total_entries) * 100

print(f"Number of missing values: {missing_values_count}")
print(f"Percentage of missing values: {percentage_missing:.2f}%")
# Out:
# Number of missing values: 9941
# Percentage of missing values: 36.00%

# %%
#standardize Airport.Code to all uppercase
airplane_df['Airport.Code'] = airplane_df['Airport.Code'].str.upper()

# %%
# Set the option to display all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the DataFrame
print(airplane_df.head())

# Reset the option to its default value

pd.reset_option('display.max_columns')
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20170710X52551           Accident      NYC79AA106  1979-09-17
# 20020909X01562           Accident      SEA82DA022  1982-01-01
# 20020909X01561           Accident      NYC82DA015  1982-01-01
# 20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 20020917X02134           Accident      FTW82FRA14  1982-01-02
#
#                         Location        Country   Latitude  Longitude  \
# Event.Id
# 20170710X52551        BOSTON, MA  United States  42.445277 -70.758333
# 20020909X01562       PULLMAN, WA  United States        NaN        NaN
# 20020909X01561  EAST HANOVER, NJ  United States        NaN        NaN
# 20020917X02148         HOMER, LA  United States        NaN        NaN
# 20020917X02134        HEARNE, TX  United States        NaN        NaN
#
#                Airport.Code        Airport.Name Injury.Severity  \
# Event.Id
# 20170710X52551          NaN                 NaN       Non-Fatal
# 20020909X01562          NaN  BLACKBURN AG STRIP       Non-Fatal
# 20020909X01561          N58             HANOVER       Non-Fatal
# 20020917X02148          NaN                 NaN       Non-Fatal
# 20020917X02134          T72    HEARNE MUNICIPAL        Fatal(1)
#
#                Aircraft.damage Aircraft.Category Registration.Number  \
# Event.Id
# 20170710X52551     Substantial          Airplane              CF-TLU
# 20020909X01562     Substantial          Airplane              N2482N
# 20020909X01561     Substantial          Airplane              N7967Q
# 20020917X02148       Destroyed          Airplane              N14779
# 20020917X02134       Destroyed          Airplane              N758SK
#
#                              Make   Model Amateur.Built  Number.of.Engines  \
# Event.Id
# 20170710X52551  Mcdonnell Douglas     DC9            No                2.0
# 20020909X01562             Cessna     140            No                1.0
# 20020909X01561             Cessna    401B            No                2.0
# 20020917X02148           Bellanca  17-30A            No                1.0
# 20020917X02134             Cessna   R172K            No                1.0
#
#                   Engine.Type            FAR.Description Schedule  \
# Event.Id
# 20170710X52551      Turbo Fan          Part 129: Foreign     SCHD
# 20020909X01562  Reciprocating  Part 91: General Aviation      NaN
# 20020909X01561  Reciprocating  Part 91: General Aviation      NaN
# 20020917X02148  Reciprocating  Part 91: General Aviation      NaN
# 20020917X02134  Reciprocating  Part 91: General Aviation      NaN
#
#                Purpose.of.flight Air.carrier  Total.Fatal.Injuries  \
# Event.Id
# 20170710X52551               NaN  Air Canada                   NaN
# 20020909X01562          Personal         NaN                   0.0
# 20020909X01561          Business         NaN                   0.0
# 20020917X02148          Personal         NaN                   0.0
# 20020917X02134          Personal         NaN                   1.0
#
#                 Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# Event.Id
# 20170710X52551                     NaN                   1.0             44.0
# 20020909X01562                     0.0                   0.0              2.0
# 20020909X01561                     0.0                   0.0              2.0
# 20020917X02148                     0.0                   1.0              0.0
# 20020917X02134                     0.0                   0.0              0.0
#
#                Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20170710X52551               VMC                 Climb  Probable Cause
# 20020909X01562               VMC               Takeoff  Probable Cause
# 20020909X01561               IMC               Landing  Probable Cause
# 20020917X02148               IMC                Cruise  Probable Cause
# 20020917X02134               IMC               Takeoff  Probable Cause
#
#                Publication.Date State
# Event.Id
# 20170710X52551       19-09-2017    MA
# 20020909X01562       01-01-1982    WA
# 20020909X01561       01-01-1982    NJ
# 20020917X02148       02-01-1983    LA
# 20020917X02134       02-01-1983    TX

# %%
airplane_df.describe()

# %%
top_makes = airplane_df['Make'].value_counts().head(10).index
top_makes_df = airplane_df[airplane_df['Make'].isin(top_makes)]

sns.boxplot(x = 'Make', y = 'Total.Fatal.Injuries', data = top_makes_df)
plt.show()
# Out:
# /Users/juank/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/juank/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/juank/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Make Cleaning

# %%
airplane_df["Make"].value_counts()
# Out:
# Make
# CESSNA             4867
# Cessna             3608
# PIPER              2805
# Piper              1910
# BOEING             1037
#                    ...
# GLINES                1
# RAMMEL THOMAS W       1
# HEMMER                1
# W.H. Hunnicutt        1
# ORLICAN S R O         1
# Name: count, Length: 3874, dtype: int64

# %%
airplane_df["Make"] = airplane_df["Make"].str.upper()

# %%
# Cessna
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["CESSNA AIRCRAFT CO", "CESSNA AIRCRAFT COMPANY", "CESSNA AIRCRAFT", "CESSNA ECTOR", "CESSNA SKYHAWK II", "CESSNA AIRCRAFT CO"], value="CESSNA")

# %%
# Piper
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["PIPER AIRCRAFT INC", "PIPER AIRCRAFT CORPORATION", "PIPER AIRCRAFT", "NEW PIPER AIRCRAFT INC", "'PIPER AIRCRAFT, INC.'", "NEW PIPER", "PIPER AEROSTAR", "PIPER-AEROSTAR", "PIPER PAWNEE", "JETPROP DLX PIPER"], value="PIPER")

# %%
# The Beechcraft and Hawker companies merged, it is now called Beechcraft
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["BEECHCRAFT", "HAWKER BEECHCRAFT", "HAWKER BEECHCRAFT CORP", "HAWKER BEECHCRAFT CORPORATION", "HAWKER BEECHCRAFT CORP.", "BEECH AIRCRAFT CORPORATION", "BEECH AIRCRAFT", "HAWKER BEECH", "HAWKER-BEECHCRAFT", "BEECH AIRCRAFT CO.", "BEECH AIRCRAFT CORP", "BEECHCRAFT CORPORATION", "HAWKER-BEECHCRAFT CORPORATION", "HAWKER", "HAWKER SIDDELEY", "HAWKER AIRCRAFT LTD"], value="BEECH")

# %%
# Stearman merged into Boeing
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["THE BOEING COMPANY", "BOEING COMPANY", "BOEING STEARMAN", "'BOEING COMPANY, LONG BEACH DIV'", "BOEING-STEARMAN", "BOEING 777-306ER", "BOEING (STEARMAN)", "BOEING COMMERCIAL AIRPLANE GRO", "BOEING OF CANADA/DEHAV DIV", "STEARMAN", "STEARMAN AIRCRAFT"], value="BOEING")

# %%
# Mooney
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["MOONEY AIRCRAFT CORP.", "MOONEY AIRPLANE CO INC", "MOONEY INTERNATIONAL CORP", "MOONEY AIRCRAFT CORPORATION", "MOONEY AIRCRAFT CORP", "'MOONEY AIRPLANE COMPANY, INC.'"], value="MOONEY")

# %%
# Grumann and Northrop merged
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["GRUMMAN ACFT ENG COR-SCHWEIZER", "GRUMMAN AMERICAN AVN. CORP", "GRUMMAN AMERICAN", "GRUMMAN-SCHWEIZER", "GRUMMAN AIRCRAFT ENG CORP", "GRUMMAN ACFT ENG", "GRUMMAN AMERICAN AVIATION", "GRUMMAN SCHWEIZER", "GRUMMAN AIRCRAFT COR-SCHWEIZER", "GRUMMAN AMERICAN AVN. CORP", "GRUMMAN AMERICAN CORPORATION", "GRUMMAN AIRCRAFT", "GRUMMAN ACFT ENG COR", "GRUMMAN AMERICAN AVIATION CORP", "NORTHROP"], value="GRUMMAN")

# %%
# Airbus
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["AIRBUS INDUSTRIE"], value="AIRBUS")

# %%
# Maule
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["MAULE AIRCRAFT CORP"], value="MAULE")

# %%
# Aeronca
airplane_df["Make"] = airplane_df["Make"].replace(to_replace=["AERONCA AIRCRAFT CORPORATION", "AERONCA CHAMPION", "AERONCA CHAMP"], value="AERONCA")

# %%
# Top 10
airplane_df["Make"].value_counts().head(10)
# Out:
# Make
# CESSNA      8525
# PIPER       4772
# BEECH       1785
# BOEING      1371
# MOONEY       466
# GRUMMAN      381
# AIRBUS       288
# BELLANCA     282
# MAULE        233
# AERONCA      232
# Name: count, dtype: int64

# %%
# Remove any Make that have a value count under 232
airplane_df.groupby("Make").filter(lambda x : len(x)>=232)
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20020909X01562           Accident      SEA82DA022  1982-01-01
# 20020909X01561           Accident      NYC82DA015  1982-01-01
# 20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 20020917X02134           Accident      FTW82FRA14  1982-01-02
# 20020917X02117           Accident      FTW82FPG08  1982-01-02
# ...                           ...             ...         ...
# 20221211106438           Accident      ERA23LA083  2022-12-09
# 20221215106460           Accident      ERA23LA088  2022-12-10
# 20221212106444           Accident      ERA23LA085  2022-12-12
# 20221213106455           Accident      WPR23LA065  2022-12-13
# 20221219106470           Accident      ERA23LA091  2022-12-16
#
#                         Location        Country Latitude Longitude  \
# Event.Id
# 20020909X01562       PULLMAN, WA  United States      NaN       NaN
# 20020909X01561  EAST HANOVER, NJ  United States      NaN       NaN
# 20020917X02148         HOMER, LA  United States      NaN       NaN
# 20020917X02134        HEARNE, TX  United States      NaN       NaN
# 20020917X02117   LITTLE ROCK, AR  United States      NaN       NaN
# ...                          ...            ...      ...       ...
# 20221211106438  HAWKINSVILLE, GA  United States  321814N  0832534W
# 20221215106460     ALABASTER, AL  United States  331040N  0086470W
# 20221212106444     KNOXVILLE, TN  United States  355745N  0835218W
# 20221213106455     LEWISTOWN, MT  United States  047257N  0109280W
# 20221219106470   BROOKSVILLE, FL  United States  282825N  0822719W
#
#                Airport.Code                 Airport.Name Injury.Severity  ...  \
# Event.Id                                                                  ...
# 20020909X01562          NaN           BLACKBURN AG STRIP       Non-Fatal  ...
# 20020909X01561          N58                      HANOVER       Non-Fatal  ...
# 20020917X02148          NaN                          NaN       Non-Fatal  ...
# 20020917X02134          T72             HEARNE MUNICIPAL        Fatal(1)  ...
# 20020917X02117          NaN                          NaN        Fatal(2)  ...
# ...                     ...                          ...             ...  ...
# 20221211106438          51A  HAWKINSVILLE-PULASKI COUNTY           Minor  ...
# 20221215106460          EET                          NaN       Non-Fatal  ...
# 20221212106444          DKX    KNOXVILLE DOWNTOWN ISLAND       Non-Fatal  ...
# 20221213106455         KLWT   Lewiston Municipal Airport       Non-Fatal  ...
# 20221219106470          BKV   BROOKSVILLE-TAMPA BAY RGNL           Minor  ...
#
#                                       Air.carrier Total.Fatal.Injuries  \
# Event.Id
# 20020909X01562                                NaN                  0.0
# 20020909X01561                                NaN                  0.0
# 20020917X02148                                NaN                  0.0
# 20020917X02134                                NaN                  1.0
# 20020917X02117                                NaN                  2.0
# ...                                           ...                  ...
# 20221211106438                                NaN                  0.0
# 20221215106460                                NaN                  0.0
# 20221212106444  Knoxville Flight Training Academy                  0.0
# 20221213106455                                NaN                  0.0
# 20221219106470                   GERBER RICHARD E                  0.0
#
#                Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20020909X01562                    0.0                  0.0             2.0
# 20020909X01561                    0.0                  0.0             2.0
# 20020917X02148                    0.0                  1.0             0.0
# 20020917X02134                    0.0                  0.0             0.0
# 20020917X02117                    0.0                  0.0             0.0
# ...                               ...                  ...             ...
# 20221211106438                    1.0                  0.0             0.0
# 20221215106460                    0.0                  0.0             2.0
# 20221212106444                    0.0                  0.0             1.0
# 20221213106455                    0.0                  0.0             1.0
# 20221219106470                    1.0                  0.0             0.0
#
#                Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20020909X01562               VMC                Takeoff  Probable Cause
# 20020909X01561               IMC                Landing  Probable Cause
# 20020917X02148               IMC                 Cruise  Probable Cause
# 20020917X02134               IMC                Takeoff  Probable Cause
# 20020917X02117               IMC                 Cruise  Probable Cause
# ...                          ...                    ...             ...
# 20221211106438               VMC                    NaN             NaN
# 20221215106460               NaN                    NaN             NaN
# 20221212106444               VMC                    NaN             NaN
# 20221213106455               NaN                    NaN             NaN
# 20221219106470               VMC                    NaN             NaN
#
#                Publication.Date State
# Event.Id
# 20020909X01562       01-01-1982    WA
# 20020909X01561       01-01-1982    NJ
# 20020917X02148       02-01-1983    LA
# 20020917X02134       02-01-1983    TX
# 20020917X02117       02-01-1983    AR
# ...                         ...   ...
# 20221211106438       15-12-2022    GA
# 20221215106460       19-12-2022    AL
# 20221212106444       15-12-2022    TN
# 20221213106455       14-12-2022    MT
# 20221219106470       23-12-2022    FL
#
# [18335 rows x 31 columns]

# %% [markdown]
# ## Event Date Filtering

# %%
# # Filtering out dates before January 01, 1998
# airplane_df["Event.Date"] = pd.to_datetime(df["Event.Date"])
# airplane_df[airplane_df["Event.Date"] > "1998-01-01"]
# Out:
# Empty DataFrame
# Columns: [Investigation.Type, Accident.Number, Event.Date, Location, Country, Latitude, Longitude, Airport.Code, Airport.Name, Injury.Severity, Aircraft.damage, Aircraft.Category, Registration.Number, Make, Model, Amateur.Built, Number.of.Engines, Engine.Type, FAR.Description, Schedule, Purpose.of.flight, Air.carrier, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Weather.Condition, Broad.phase.of.flight, Report.Status, Publication.Date, State]
# Index: []
#
# [0 rows x 31 columns]

# %%
airplane_df.to_csv('airplane_df.csv')
