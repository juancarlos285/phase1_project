# %%
import pandas as pd
import datetime

# %%
pd.set_option("display.max_columns", None)

# %%
# Read the CSV
airplane_df = pd.read_csv("../airplane_df.csv", encoding = "latin-1", low_memory = False)

# %%
# United States (and its territories) only
airplane_df = airplane_df[airplane_df["Country"] == "United States"]

# %%
# Airplane Damage
airplane_df["Aircraft.damage"].value_counts()
# Out:
# Aircraft.damage
# Substantial    20523
# Destroyed       2673
# Minor            508
# Unknown           43
# Name: count, dtype: int64

# %%
# Drop null values in Aircraft.damage column
airplane_df.dropna(subset=["Aircraft.damage"], inplace = True)

# %%
# KEEP THIS CODE
# Analyzing data if Unknown should be dropped
# unknown_aircraft_damage = airplane_df[airplane_df["Aircraft.damage"] == "Unknown"]

# %%
# KEEP THIS CODE
# Analyzing data if Unknown should be dropped
# unknown_aircraft_damage.sort_values("Total.Uninjured", ascending=False)

# %% [markdown]
# Conclusion: Drop Unknown!

# %%
# Drop Aircraft Damage with the Unknown value
airplane_df = airplane_df.drop(airplane_df[airplane_df["Aircraft.damage"] == "Unknown"].index)

# %%
# Analyizing injuries on Destroyed Aircraft Damage
destroyed_aircraft_damage = airplane_df[airplane_df["Aircraft.damage"] == "Destroyed"]

# %%
# Analyizing injuries on Destroyed Aircraft Damage
destroyed_aircraft_damage.sort_values("Total.Fatal.Injuries", ascending=False).head(10)
# destroyed_aircraft_damage.sort_values("Total.Serious.Injuries", ascending=False).head(10)
# destroyed_aircraft_damage.sort_values("Total.Minor.Injuries", ascending=False).head(10)
# destroyed_aircraft_damage.sort_values("Total.Uninjured", ascending=False).head(10)
# Out:
#             Event.Id Investigation.Type Accident.Number  Event.Date  \
# 3344  20001208X08606           Accident      DCA97MA058  1997-08-06
# 3568  20020123X00104           Accident      DCA01MA063  2001-09-11
# 8480  20090213X13613           Accident      DCA09MA027  2009-02-13
# 3270  20001211X14270           Accident      DCA92MA025  1992-03-22
# 3198  20001214X37718           Accident      ATL85MA286  1985-09-29
# 3271  20001211X14468           Accident      LAX92MA183  1992-04-22
# 2683  20020917X04782           Accident      LAX83FA012  1982-10-17
# 4276  20041020X01659           Accident      DCA05MA004  2004-10-19
# 1868  20020917X03242           Accident      FTW82AA299  1982-07-28
# 3308  20001207X04585           Accident      NYC95MA220  1995-09-10
#
#                  Location        Country Latitude Longitude Airport.Code  \
# 3344      NIMITZ HILL, GU  United States      NaN       NaN         KGUM
# ...

# %%
# Drop Purpose of Flight Skydiving
destroyed_aircraft_damage = destroyed_aircraft_damage.drop(destroyed_aircraft_damage[destroyed_aircraft_damage["Purpose.of.flight"] == "Skydiving"].index)

# %%
destroyed_aircraft_damage.sort_values("Total.Fatal.Injuries", ascending=False).head(10)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 3344   20001208X08606           Accident      DCA97MA058  1997-08-06
# 3568   20020123X00104           Accident      DCA01MA063  2001-09-11
# 8480   20090213X13613           Accident      DCA09MA027  2009-02-13
# 3270   20001211X14270           Accident      DCA92MA025  1992-03-22
# 4276   20041020X01659           Accident      DCA05MA004  2004-10-19
# 1868   20020917X03242           Accident      FTW82AA299  1982-07-28
# 23937  20190630X33829           Accident      CEN19MA190  2019-06-30
# 3209   20001213X30060           Accident     DCA87MA018A  1987-01-15
# 3208   20001213X30060           Accident     DCA87MA018B  1987-01-15
# 6522   20071017X01609           Accident      LAX08MA007  2007-10-07
#
#                   Location        Country   Latitude    Longitude  \
# 3344       NIMITZ HILL, GU  United States        NaN          NaN
# 3568     NEW YORK CITY, NY  United States        NaN          NaN
# ...

# %%
# Fatal Injuries <= 70 to find regional aircraft
regional_destroyed = destroyed_aircraft_damage[destroyed_aircraft_damage['Total.Fatal.Injuries'] <= 70].sort_values(by='Total.Fatal.Injuries', ascending=False)

# %%
# Fatal Injuries <= 70 to find regional aircraft
regional_destroyed.sort_values("Total.Fatal.Injuries", ascending=False).head(10)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 3568   20020123X00104           Accident      DCA01MA063  2001-09-11
# 8480   20090213X13613           Accident      DCA09MA027  2009-02-13
# 3270   20001211X14270           Accident      DCA92MA025  1992-03-22
# 4276   20041020X01659           Accident      DCA05MA004  2004-10-19
# 1868   20020917X03242           Accident      FTW82AA299  1982-07-28
# 3208   20001213X30060           Accident     DCA87MA018B  1987-01-15
# 6522   20071017X01609           Accident      LAX08MA007  2007-10-07
# 23937  20190630X33829           Accident      CEN19MA190  2019-06-30
# 3209   20001213X30060           Accident     DCA87MA018A  1987-01-15
# 15114  20130707X14623           Accident      DCA13MA121  2013-07-07
#
#                   Location        Country   Latitude    Longitude  \
# 3568     NEW YORK CITY, NY  United States        NaN          NaN
# 8480   CLARENCE CENTER, NY  United States    043040N     0078385W
# ...

# %%
regional_destroyed.sort_values("Total.Uninjured", ascending=False).head(10)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 134    20020917X01909           Accident      DCA82AA013  1982-01-23
# 15111  20130707X83745           Accident      DCA13MA120  2013-07-06
# 27265  20211019104129           Accident      DCA22MA009  2021-10-19
# 24226  20190821X63931           Accident      WPR19FA230  2019-08-21
# 28627  20220920105974           Accident      WPR22LA353  2022-09-20
# 3237   20001212X22846           Accident     ATL90FA095B  1990-04-09
# 22469  20180721X41413           Accident      WPR18FA201  2018-07-21
# 24720  20200102X93921           Accident      ERA20LA062  2019-12-28
# 9503   20090915X12034           Accident      ERA09LA523  2009-09-15
# 2066   20020917X03606           Accident      LAX82DA299  1982-08-14
#
#                 Location        Country Latitude Longitude Airport.Code  \
# 134           BOSTON, MA  United States      NaN       NaN          NaN
# ...

# %%
# Analyizing data after January 1998
destroyed_aircraft_damage["Event.Date"] = pd.to_datetime(destroyed_aircraft_damage["Event.Date"])
eventdate_destroyed_aircraft_damage = destroyed_aircraft_damage[destroyed_aircraft_damage ["Event.Date"] > "1998-01-01"]
fatal_eventdate_destroyed_aircraft_damage = eventdate_destroyed_aircraft_damage.sort_values("Total.Fatal.Injuries", ascending=False).head(10)
fatal_eventdate_destroyed_aircraft_damage
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 3568   20020123X00104           Accident      DCA01MA063 2001-09-11
# 8480   20090213X13613           Accident      DCA09MA027 2009-02-13
# 4276   20041020X01659           Accident      DCA05MA004 2004-10-19
# 23937  20190630X33829           Accident      CEN19MA190 2019-06-30
# 6522   20071017X01609           Accident      LAX08MA007 2007-10-07
# 15114  20130707X14623           Accident      DCA13MA121 2013-07-07
# 18460  20151110X65615           Accident      CEN16MA036 2015-11-10
# 24634  20191130X65423           Accident      CEN20FA022 2019-11-30
# 25341  20200705X32345           Accident      WPR20FA206 2020-07-05
# 7726   20080806X01166           Accident      DCA08MA085 2008-07-31
#
#                   Location        Country   Latitude    Longitude  \
# 3568     NEW YORK CITY, NY  United States        NaN          NaN
# 8480   CLARENCE CENTER, NY  United States    043040N     0078385W
# ...

# %%
# KEEP THIS
# Analyizing injuries on Minor Aircraft Damage
minor_aircraft_damage = airplane_df[airplane_df["Aircraft.damage"] == "Minor"]
minor_aircraft_damage
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 11     20020917X02333           Incident      LAX82IA034  1982-01-03
# 28     20020917X01764           Incident      ATL82IA029  1982-01-05
# 66     20020917X01765           Incident      ATL82IA034  1982-01-12
# 100    20020917X01766           Incident      ATL82IA038  1982-01-19
# 112    20020917X02334           Incident      LAX82IA044  1982-01-20
# ...               ...                ...             ...         ...
# 28370  20220805105670           Accident      ERA22LA358  2022-07-28
# 28420  20220807105676           Accident      ERA22LA362  2022-08-07
# 28566  20220908105887           Accident      ERA22LA402  2022-09-07
# 28692  20221006106074           Accident      ANC23FA001  2022-10-06
# 28761  20221027106213           Accident      ERA23LA043  2022-10-27
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
# Drop Purpose of Flight is Skydiving
minor_aircraft_damage = minor_aircraft_damage.drop(minor_aircraft_damage[minor_aircraft_damage["Purpose.of.flight"] == "Skydiving"].index)

# %%
# KEEP THIS
# Analyizing injuries on Minor Aircraft Damage
minor_aircraft_damage.sort_values("Total.Fatal.Injuries", ascending=False).head(10)
# minor_aircraft_damage.sort_values("Total.Serious.Injuries", ascending=False).head(10)
# minor_aircraft_damage.sort_values("Total.Minor.Injuries", ascending=False).head(10)
# minor_aircraft_damage.sort_values("Total.Uninjured", ascending=False).head(10)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 14682  20130330X85743           Accident      ERA13LA183  2013-03-29
# 28692  20221006106074           Accident      ANC23FA001  2022-10-06
# 20720  20170619X92534           Accident      CEN17LA234  2017-06-17
# 28420  20220807105676           Accident      ERA22LA362  2022-08-07
# 12824  20111129X24104           Accident      CEN12FA088  2011-11-30
# 2169   20020917X02699           Accident      ANC82DAG48  1982-08-22
# 17717  20150608X04410           Accident      ANC15LA035  2015-06-04
# 15317  20130822X63331           Accident      CEN13LA500  2013-08-16
# 23426  20190313X23730           Accident      WPR19FA095  2019-03-14
# 10868  20100827X64057           Accident      ERA10LA446  2010-08-27
#
#                Location        Country Latitude Longitude Airport.Code  \
# 14682   COLLEGEDALE, TN  United States  035240N  0085112W          NaN
# ...

# %%
# # Analyizing data after January 1998
# minor_aircraft_damage["Event.Date"] = pd.to_datetime(minor_aircraft_damage["Event.Date"])
# eventdate_minor_aircraft_damage = minor_aircraft_damage[minor_aircraft_damage ["Event.Date"] > "1998-01-01"]
# eventdate_minor_aircraft_damage
