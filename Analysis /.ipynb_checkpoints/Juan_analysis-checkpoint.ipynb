# %%
import pandas as pd
df = pd.read_csv('../airplane_df.csv')
# Out:
# /var/folders/ws/w4d9z41n7vj1pg3kqv95frm80000gn/T/ipykernel_93871/1343205581.py:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../airplane_df.csv')

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20170710X52551           Accident      NYC79AA106         NaN
# 1      20020909X01562           Accident      SEA82DA022         NaN
# 2      20020909X01561           Accident      NYC82DA015         NaN
# 3      20020917X02148           Accident      FTW82FRJ07         NaN
# 4      20020917X02134           Accident      FTW82FRA14         NaN
# ...               ...                ...             ...         ...
# 28851  20221213106455           Accident      WPR23LA065         NaN
# 28852  20221215106463           Accident      ERA23LA090         NaN
# 28853  20221219106475           Accident      WPR23LA069         NaN
# 28854  20221219106470           Accident      ERA23LA091         NaN
# 28855  20221227106497           Accident      WPR23LA075         NaN
#
#                Location        Country   Latitude   Longitude Airport.Code  \
# ...
